# %%
import numpy as np
from pathlib import Path
import cv2
import math
import matplotlib as plt 
import matplotlib.pyplot as plt

# %%
import numpy as np

file_path = '20251212-162426255.bin'

# Load the data. You MUST specify the dtype (float32, int64, etc.)
# If you don't know it, float32 is a common default for sensor/scientific data.
data = np.fromfile(file_path, dtype=np.float32)

print(data[0:100]) # View the first 10 elements
# Out:
# [ 1.1920929e-07  9.6950184e+24  6.0649205e+23  9.6967893e+24
#   2.6041505e+33  2.5431157e+30  1.0151108e+31  9.9340457e+27
#   3.9753108e+28  1.0879741e-19  3.9744645e+28  1.0876102e-19
#   9.7015116e+24  3.7903447e+22  2.3509887e-38  1.5777218e-30
#   1.9101426e-06  1.9131694e-06  1.5135092e+23  3.6231973e-41
#   7.4619493e-09  7.4614945e-09  7.2877260e-12  1.1938391e-07
#   1.8652031e-09  2.2027142e+12  3.0562282e-05  2.9855073e-08
#   4.8899651e-04  2.9849616e-08  4.6630078e-10  4.8904121e-04
#   4.6634341e-10  9.8607613e-32  7.4774107e-09  1.9100262e-06
#   4.6631499e-10  6.4623485e-27  1.4806484e+20  2.1539717e+09
#   1.0869484e-19  1.9102590e-06  1.8652599e-09  3.8518599e-34
#   1.9102590e-06  1.8652599e-09  2.3509887e-38  2.3509887e-38
#   1.6543612e-24  4.6634341e-10  4.6648552e-10  4.8899651e-04
#   1.8653736e-09  1.8652599e-09  7.6412689e-06  1.7763568e-15
#   5.8052152e-40  9.1841101e-41  2.3694996e-38  1.5061021e-38
# ...
